# %%
import pandas as pd
df = pd.read_feather(f'data/nyc_buses_with_passenger_counts_20210401_20210630_citywide_features.feather')

# %%
# fix next stop id
df['next_stop_id_cleaned'] = df['next_stop_id_cleaned'].astype(int)

# %% [markdown]
# # one-hot encode route_short

# %%
# https://queirozf.com/entries/one-hot-encoding-a-feature-on-a-pandas-dataframe-an-example
df = pd.concat([df,pd.get_dummies(df['route_short'], prefix='route_short_')],axis=1)

# %%
# # one-hot encode next_stop_id (omitted not enough RAM)
# # https://queirozf.com/entries/one-hot-encoding-a-feature-on-a-pandas-dataframe-an-example
# df = pd.concat([df,pd.get_dummies(df['next_stop_id_cleaned'], prefix='stop_id_')],axis=1)

# %%
# fix vehicle_id
df['vehicle_id'] = df['vehicle_id'].astype(int)
cols = df.columns.tolist()

# %%
[x for x in cols]
# Out:
# ['route_short',
#  'vehicle_id',
#  'month',
#  'week',
#  'day',
#  'hour',
#  'day_of_week',
#  'is_weekend',
#  'day_of_week_sin',
#  'day_of_week_cos',
#  'hour_norm',
#  'hour_cos',
#  'hour_sin',
#  'cluster_id',
#  'lat',
#  'lon',
#  'direction',
#  'next_stop_id_cleaned',
#  'next_stop_d',
#  'next_stop_d_along_route',
#  'passenger_count',
#  'route_short__B1',
#  'route_short__B11',
#  'route_short__B12',
#  'route_short__B13',
#  'route_short__B14',
#  'route_short__B15',
#  'route_short__B16',
#  'route_short__B17',
#  'route_short__B2',
#  'route_short__B20',
#  'route_short__B24',
#  'route_short__B25',
#  'route_short__B26',
#  'route_short__B3',
#  'route_short__B31',
#  'route_short__B32',
#  'route_short__B35',
#  'route_short__B36',
#  'route_short__B37',
#  'route_short__B38',
#  'route_short__B39',
#  'route_short__B4',
#  'route_short__B41',
#  'route_short__B42',
#  'route_short__B43',
#  'route_short__B44',
#  'route_short__B45',
#  'route_short__B46',
#  'route_short__B47',
#  'route_short__B48',
#  'route_short__B49',
#  'route_short__B52',
#  'route_short__B54',
#  'route_short__B57',
#  'route_short__B6',
#  'route_short__B60',
#  'route_short__B61',
#  'route_short__B62',
#  'route_short__B63',
#  'route_short__B64',
#  'route_short__B65',
#  'route_short__B67',
#  'route_short__B68',
#  'route_short__B69',
#  'route_short__B7',
#  'route_short__B70',
#  'route_short__B74',
#  'route_short__B8',
#  'route_short__B82',
#  'route_short__B83',
#  'route_short__B84',
#  'route_short__B9',
#  'route_short__B99',
#  'route_short__Bx1',
#  'route_short__Bx10',
#  'route_short__Bx11',
#  'route_short__Bx12',
#  'route_short__Bx13',
#  'route_short__Bx15',
#  'route_short__Bx16',
#  'route_short__Bx17',
#  'route_short__Bx18',
#  'route_short__Bx19',
#  'route_short__Bx2',
#  'route_short__Bx20',
#  'route_short__Bx21',
#  'route_short__Bx22',
#  'route_short__Bx24',
#  'route_short__Bx26',
#  'route_short__Bx27',
#  'route_short__Bx28',
#  'route_short__Bx29',
#  'route_short__Bx3',
#  'route_short__Bx30',
#  'route_short__Bx31',
#  'route_short__Bx32',
#  'route_short__Bx33',
#  'route_short__Bx34',
#  'route_short__Bx35',
#  'route_short__Bx36',
#  'route_short__Bx38',
#  'route_short__Bx39',
#  'route_short__Bx4',
#  'route_short__Bx40',
#  'route_short__Bx41',
#  'route_short__Bx42',
#  'route_short__Bx46',
#  'route_short__Bx4A',
#  'route_short__Bx5',
#  'route_short__Bx6',
#  'route_short__Bx7',
#  'route_short__Bx8',
#  'route_short__Bx9',
#  'route_short__Bx99',
#  'route_short__M1',
#  'route_short__M10',
#  'route_short__M100',
#  'route_short__M101',
#  'route_short__M102',
#  'route_short__M103',
#  'route_short__M104',
#  'route_short__M106',
#  'route_short__M11',
#  'route_short__M116',
#  'route_short__M12',
#  'route_short__M15',
#  'route_short__M2',
#  'route_short__M20',
#  'route_short__M21',
#  'route_short__M22',
#  'route_short__M3',
#  'route_short__M31',
#  'route_short__M35',
#  'route_short__M4',
#  'route_short__M42',
#  'route_short__M5',
#  'route_short__M50',
#  'route_short__M55',
#  'route_short__M57',
#  'route_short__M66',
#  'route_short__M7',
#  'route_short__M72',
#  'route_short__M8',
#  'route_short__M9',
#  'route_short__M96',
#  'route_short__M98',
#  'route_short__M99',
#  'route_short__Q1',
#  'route_short__Q12',
#  'route_short__Q13',
#  'route_short__Q15',
#  'route_short__Q15A',
#  'route_short__Q16',
#  'route_short__Q17',
#  'route_short__Q2',
#  'route_short__Q20A',
#  'route_short__Q20B',
#  'route_short__Q24',
#  'route_short__Q26',
#  'route_short__Q27',
#  'route_short__Q28',
#  'route_short__Q3',
#  'route_short__Q30',
#  'route_short__Q31',
#  'route_short__Q32',
#  'route_short__Q36',
#  'route_short__Q4',
#  'route_short__Q42',
#  'route_short__Q43',
#  'route_short__Q46',
#  'route_short__Q48',
#  'route_short__Q5',
#  'route_short__Q54',
#  'route_short__Q55',
#  'route_short__Q56',
#  'route_short__Q58',
#  'route_short__Q59',
#  'route_short__Q76',
#  'route_short__Q77',
#  'route_short__Q83',
#  'route_short__Q84',
#  'route_short__Q85',
#  'route_short__Q88',
#  'route_short__S40',
#  'route_short__S42',
#  'route_short__S44',
#  'route_short__S46',
#  'route_short__S48',
#  'route_short__S51',
#  'route_short__S52',
#  'route_short__S53',
#  'route_short__S54',
#  'route_short__S55',
#  'route_short__S56',
#  'route_short__S57',
#  'route_short__S59',
#  'route_short__S61',
#  'route_short__S62',
#  'route_short__S66',
#  'route_short__S74',
#  'route_short__S76',
#  'route_short__S78',
#  'route_short__S81',
#  'route_short__S84',
#  'route_short__S86',
#  'route_short__S89',
#  'route_short__S90',
#  'route_short__S91',
#  'route_short__S92',
#  'route_short__S93',
#  'route_short__S94',
#  'route_short__S96',
#  'route_short__S98',
#  'route_short__SIM1',
#  'route_short__SIM10',
#  'route_short__SIM11',
#  'route_short__SIM15',
#  'route_short__SIM1C',
#  'route_short__SIM2',
#  'route_short__SIM22',
#  'route_short__SIM25',
#  'route_short__SIM26',
#  'route_short__SIM3',
#  'route_short__SIM30',
#  'route_short__SIM31',
#  'route_short__SIM32',
#  'route_short__SIM33',
#  'route_short__SIM33C',
#  'route_short__SIM34',
#  'route_short__SIM35',
#  'route_short__SIM3C',
#  'route_short__SIM4',
#  'route_short__SIM4C',
#  'route_short__SIM4X',
#  'route_short__SIM5',
#  'route_short__SIM6',
#  'route_short__SIM7',
#  'route_short__SIM8',
#  'route_short__SIM8X',
#  'route_short__SIM9',
#  'route_short__X27',
#  'route_short__X28',
#  'route_short__X37',
#  'route_short__X38',
#  'route_short__X63',
#  'route_short__X64',
#  'route_short__X68']

# %% [markdown]
# # train-test split

# %%
base_train_columns = ['vehicle_id',
 'month',
 'week',
 'day',
 'hour',
 'day_of_week',
 'is_weekend',
 'day_of_week_sin',
 'day_of_week_cos',
 'hour_norm',
 'hour_cos',
 'hour_sin',
 'cluster_id',
 'lat',
 'lon',
 'direction',
 'next_stop_id_cleaned',
 'next_stop_d',
 'next_stop_d_along_route',
 'route_short__B1',
 'route_short__B11',
 'route_short__B12',
 'route_short__B13',
 'route_short__B14',
 'route_short__B15',
 'route_short__B16',
 'route_short__B17',
 'route_short__B2',
 'route_short__B20',
 'route_short__B24',
 'route_short__B25',
 'route_short__B26',
 'route_short__B3',
 'route_short__B31',
 'route_short__B32',
 'route_short__B35',
 'route_short__B36',
 'route_short__B37',
 'route_short__B38',
 'route_short__B39',
 'route_short__B4',
 'route_short__B41',
 'route_short__B42',
 'route_short__B43',
 'route_short__B44',
 'route_short__B45',
 'route_short__B46',
 'route_short__B47',
 'route_short__B48',
 'route_short__B49',
 'route_short__B52',
 'route_short__B54',
 'route_short__B57',
 'route_short__B6',
 'route_short__B60',
 'route_short__B61',
 'route_short__B62',
 'route_short__B63',
 'route_short__B64',
 'route_short__B65',
 'route_short__B67',
 'route_short__B68',
 'route_short__B69',
 'route_short__B7',
 'route_short__B70',
 'route_short__B74',
 'route_short__B8',
 'route_short__B82',
 'route_short__B83',
 'route_short__B84',
 'route_short__B9',
 'route_short__B99',
 'route_short__Bx1',
 'route_short__Bx10',
 'route_short__Bx11',
 'route_short__Bx12',
 'route_short__Bx13',
 'route_short__Bx15',
 'route_short__Bx16',
 'route_short__Bx17',
 'route_short__Bx18',
 'route_short__Bx19',
 'route_short__Bx2',
 'route_short__Bx20',
 'route_short__Bx21',
 'route_short__Bx22',
 'route_short__Bx24',
 'route_short__Bx26',
 'route_short__Bx27',
 'route_short__Bx28',
 'route_short__Bx29',
 'route_short__Bx3',
 'route_short__Bx30',
 'route_short__Bx31',
 'route_short__Bx32',
 'route_short__Bx33',
 'route_short__Bx34',
 'route_short__Bx35',
 'route_short__Bx36',
 'route_short__Bx38',
 'route_short__Bx39',
 'route_short__Bx4',
 'route_short__Bx40',
 'route_short__Bx41',
 'route_short__Bx42',
 'route_short__Bx46',
 'route_short__Bx4A',
 'route_short__Bx5',
 'route_short__Bx6',
 'route_short__Bx7',
 'route_short__Bx8',
 'route_short__Bx9',
 'route_short__Bx99',
 'route_short__M1',
 'route_short__M10',
 'route_short__M100',
 'route_short__M101',
 'route_short__M102',
 'route_short__M103',
 'route_short__M104',
 'route_short__M106',
 'route_short__M11',
 'route_short__M116',
 'route_short__M12',
 'route_short__M15',
 'route_short__M2',
 'route_short__M20',
 'route_short__M21',
 'route_short__M22',
 'route_short__M3',
 'route_short__M31',
 'route_short__M35',
 'route_short__M4',
 'route_short__M42',
 'route_short__M5',
 'route_short__M50',
 'route_short__M55',
 'route_short__M57',
 'route_short__M66',
 'route_short__M7',
 'route_short__M72',
 'route_short__M8',
 'route_short__M9',
 'route_short__M96',
 'route_short__M98',
 'route_short__M99',
 'route_short__Q1',
 'route_short__Q12',
 'route_short__Q13',
 'route_short__Q15',
 'route_short__Q15A',
 'route_short__Q16',
 'route_short__Q17',
 'route_short__Q2',
 'route_short__Q20A',
 'route_short__Q20B',
 'route_short__Q24',
 'route_short__Q26',
 'route_short__Q27',
 'route_short__Q28',
 'route_short__Q3',
 'route_short__Q30',
 'route_short__Q31',
 'route_short__Q32',
 'route_short__Q36',
 'route_short__Q4',
 'route_short__Q42',
 'route_short__Q43',
 'route_short__Q46',
 'route_short__Q48',
 'route_short__Q5',
 'route_short__Q54',
 'route_short__Q55',
 'route_short__Q56',
 'route_short__Q58',
 'route_short__Q59',
 'route_short__Q76',
 'route_short__Q77',
 'route_short__Q83',
 'route_short__Q84',
 'route_short__Q85',
 'route_short__Q88',
 'route_short__S40',
 'route_short__S42',
 'route_short__S44',
 'route_short__S46',
 'route_short__S48',
 'route_short__S51',
 'route_short__S52',
 'route_short__S53',
 'route_short__S54',
 'route_short__S55',
 'route_short__S56',
 'route_short__S57',
 'route_short__S59',
 'route_short__S61',
 'route_short__S62',
 'route_short__S66',
 'route_short__S74',
 'route_short__S76',
 'route_short__S78',
 'route_short__S81',
 'route_short__S84',
 'route_short__S86',
 'route_short__S89',
 'route_short__S90',
 'route_short__S91',
 'route_short__S92',
 'route_short__S93',
 'route_short__S94',
 'route_short__S96',
 'route_short__S98',
 'route_short__SIM1',
 'route_short__SIM10',
 'route_short__SIM11',
 'route_short__SIM15',
 'route_short__SIM1C',
 'route_short__SIM2',
 'route_short__SIM22',
 'route_short__SIM25',
 'route_short__SIM26',
 'route_short__SIM3',
 'route_short__SIM30',
 'route_short__SIM31',
 'route_short__SIM32',
 'route_short__SIM33',
 'route_short__SIM33C',
 'route_short__SIM34',
 'route_short__SIM35',
 'route_short__SIM3C',
 'route_short__SIM4',
 'route_short__SIM4C',
 'route_short__SIM4X',
 'route_short__SIM5',
 'route_short__SIM6',
 'route_short__SIM7',
 'route_short__SIM8',
 'route_short__SIM8X',
 'route_short__SIM9',
 'route_short__X27',
 'route_short__X28',
 'route_short__X37',
 'route_short__X38',
 'route_short__X63',
 'route_short__X64',
 'route_short__X68']

# %%
df = df.drop('route_short', axis=1)

# %% [raw]
# Split the data in time, using the first 6 weeks to predict the last 2

# %%
# look at count by week #
df.groupby('week').size()
# Out:
# week
# 17      4898
# 18    448844
# 19    500512
# 20    510184
# 21    503450
# 22    466044
# 23    491715
# 24    499244
# 25    502471
# 26    243760
# dtype: int64

# %%
# df_test = df[ (df.month >= 4 ) &  (df.month <= 5)]
df_test = df[ (df.week >= 18 ) &  (df.week <= 23)]

df_train = df[~df.index.isin(df_test.index)]

(df_train.shape, df_test.shape)
# Out:
# ((1250373, 247), (2920749, 247))

# %% [raw]
# Split training features and target

# %%
X_train_base = df_train[base_train_columns]
y_train_base = df_train.passenger_count

X_test_base = df_test[base_train_columns]
y_test_base = df_test.passenger_count

X_train_base.shape, y_train_base.shape, X_test_base.shape, y_test_base.shape
# Out:
# ((1250373, 246), (1250373,), (2920749, 246), (2920749,))

# %%
X_train_base
# Out:
#          vehicle_id  month  week  day  hour  day_of_week  is_weekend  \
# 1              7334      6    24   16     7            2       False
# 2              8671      6    25   26    18            5        True
# 5              7498      6    25   27    20            6        True
# 8              6053      6    26   29    12            1       False
# 9              2583      6    25   24     5            3       False
# ...             ...    ...   ...  ...   ...          ...         ...
# 4171110        7223      6    25   25    19            4       False
# 4171111        8275      6    24   14     8            0       False
# 4171114        7260      6    24   16     5            2       False
# 4171115        7181      6    26   28    19            0       False
# 4171119        8139      6    25   21     8            0       False
#
#          day_of_week_sin  day_of_week_cos  hour_norm  ...  route_short__SIM8  \
# 1               0.974928        -0.222521   1.912274  ...                  0
# 2              -0.974928        -0.222521   4.917275  ...                  0
# 5              -0.781831         0.623490   5.463639  ...                  0
# 8               0.781831         0.623490   3.278184  ...                  0
# 9               0.433884        -0.900969   1.365910  ...                  0
# ...                  ...              ...        ...  ...                ...
# 4171110        -0.433884        -0.900969   5.190457  ...                  0
# 4171111         0.000000         1.000000   2.185456  ...                  0
# 4171114         0.974928        -0.222521   1.365910  ...                  0
# 4171115         0.000000         1.000000   5.190457  ...                  0
# 4171119         0.000000         1.000000   2.185456  ...                  0
#
#          route_short__SIM8X  route_short__SIM9  route_short__X27  \
# 1                         0                  0                 0
# 2                         0                  0                 0
# 5                         0                  0                 0
# 8                         0                  0                 0
# 9                         0                  0                 0
# ...                     ...                ...               ...
# 4171110                   0                  0                 0
# 4171111                   0                  0                 0
# 4171114                   0                  0                 0
# 4171115                   0                  0                 0
# 4171119                   0                  0                 0
#
#          route_short__X28  route_short__X37  route_short__X38  \
# 1                       0                 0                 0
# 2                       0                 0                 0
# 5                       0                 0                 0
# 8                       0                 0                 0
# 9                       0                 0                 0
# ...                   ...               ...               ...
# 4171110                 0                 0                 0
# 4171111                 0                 0                 0
# 4171114                 0                 0                 0
# 4171115                 0                 0                 0
# 4171119                 0                 0                 0
#
#          route_short__X63  route_short__X64  route_short__X68
# 1                       0                 0                 0
# 2                       0                 0                 0
# 5                       0                 0                 0
# 8                       0                 0                 0
# 9                       0                 0                 0
# ...                   ...               ...               ...
# 4171110                 0                 0                 0
# 4171111                 0                 0                 0
# 4171114                 0                 0                 0
# 4171115                 0                 0                 0
# 4171119                 0                 0                 0
#
# [1250373 rows x 246 columns]

# %% [markdown]
# # XGBoost Regression

# %% [markdown]
# ### fit the model

# %%
import xgboost as xgb

# regr_base = XGBRegressor(learning_rate=0.05, max_depth=5, objective='reg:linear', n_estimators=100, colsample_bytree=0)
regr_base = xgb.XGBRegressor(learning_rate=0.007, max_depth=4, objective='reg:squarederror', n_estimators=200)

eval_set_base = [(X_train_base, y_train_base), (X_test_base, y_test_base)]

regr_base.fit(X=X_train_base, y=y_train_base, eval_metric=["rmsle", "mae"], eval_set=eval_set_base, verbose=True)
# Out:
# [0]	validation_0-rmsle:1.69734	validation_0-mae:8.11818	validation_1-rmsle:1.65381	validation_1-mae:7.64235
# [1]	validation_0-rmsle:1.66736	validation_0-mae:8.07932	validation_1-rmsle:1.62358	validation_1-mae:7.59119
# [2]	validation_0-rmsle:1.63863	validation_0-mae:8.03854	validation_1-rmsle:1.59501	validation_1-mae:7.54347
# [3]	validation_0-rmsle:1.61173	validation_0-mae:8.00023	validation_1-rmsle:1.56781	validation_1-mae:7.52302
# [4]	validation_0-rmsle:1.58634	validation_0-mae:7.95351	validation_1-rmsle:1.54348	validation_1-mae:7.47558
# [5]	validation_0-rmsle:1.56219	validation_0-mae:7.92152	validation_1-rmsle:1.51918	validation_1-mae:7.43393
# [6]	validation_0-rmsle:1.53911	validation_0-mae:7.87578	validation_1-rmsle:1.49651	validation_1-mae:7.38722
# [7]	validation_0-rmsle:1.51720	validation_0-mae:7.84000	validation_1-rmsle:1.47480	validation_1-mae:7.36885
# [8]	validation_0-rmsle:1.49624	validation_0-mae:7.80168	validation_1-rmsle:1.45420	validation_1-mae:7.32431
# [9]	validation_0-rmsle:1.47636	validation_0-mae:7.76973	validation_1-rmsle:1.43433	validation_1-mae:7.28406
# [10]	validation_0-rmsle:1.45741	validation_0-mae:7.73205	validation_1-rmsle:1.41559	validation_1-mae:7.24993
# [11]	validation_0-rmsle:1.43928	validation_0-mae:7.70195	validation_1-rmsle:1.39779	validation_1-mae:7.23252
# [12]	validation_0-rmsle:1.42181	validation_0-mae:7.66626	validation_1-rmsle:1.38069	validation_1-mae:7.19509
# [13]	validation_0-rmsle:1.40533	validation_0-mae:7.63608	validation_1-rmsle:1.36482	validation_1-mae:7.15487
# [14]	validation_0-rmsle:1.38932	validation_0-mae:7.60014	validation_1-rmsle:1.34888	validation_1-mae:7.12160
# [15]	validation_0-rmsle:1.37405	validation_0-mae:7.57070	validation_1-rmsle:1.33369	validation_1-mae:7.10055
# [16]	validation_0-rmsle:1.35930	validation_0-mae:7.53752	validation_1-rmsle:1.31921	validation_1-mae:7.06696
# [17]	validation_0-rmsle:1.34515	validation_0-mae:7.50624	validation_1-rmsle:1.30539	validation_1-mae:7.03289
# [18]	validation_0-rmsle:1.33148	validation_0-mae:7.47482	validation_1-rmsle:1.29199	validation_1-mae:6.99669
# [19]	validation_0-rmsle:1.31850	validation_0-mae:7.44574	validation_1-rmsle:1.27923	validation_1-mae:6.97697
# [20]	validation_0-rmsle:1.30583	validation_0-mae:7.41140	validation_1-rmsle:1.26684	validation_1-mae:6.94369
# [21]	validation_0-rmsle:1.29354	validation_0-mae:7.38352	validation_1-rmsle:1.25489	validation_1-mae:6.91315
# [22]	validation_0-rmsle:1.28172	validation_0-mae:7.35416	validation_1-rmsle:1.24358	validation_1-mae:6.89117
# [23]	validation_0-rmsle:1.27046	validation_0-mae:7.32310	validation_1-rmsle:1.23259	validation_1-mae:6.85874
# [24]	validation_0-rmsle:1.25978	validation_0-mae:7.29374	validation_1-rmsle:1.22216	validation_1-mae:6.83405
# [25]	validation_0-rmsle:1.24921	validation_0-mae:7.26803	validation_1-rmsle:1.21194	validation_1-mae:6.80922
# [26]	validation_0-rmsle:1.23913	validation_0-mae:7.24230	validation_1-rmsle:1.20232	validation_1-mae:6.78057
# [27]	validation_0-rmsle:1.22951	validation_0-mae:7.21524	validation_1-rmsle:1.19268	validation_1-mae:6.75214
# [28]	validation_0-rmsle:1.22017	validation_0-mae:7.19484	validation_1-rmsle:1.18386	validation_1-mae:6.73732
# [29]	validation_0-rmsle:1.21117	validation_0-mae:7.16824	validation_1-rmsle:1.17492	validation_1-mae:6.70791
# [30]	validation_0-rmsle:1.20252	validation_0-mae:7.14380	validation_1-rmsle:1.16666	validation_1-mae:6.68442
# [31]	validation_0-rmsle:1.19419	validation_0-mae:7.11996	validation_1-rmsle:1.15842	validation_1-mae:6.65510
# [32]	validation_0-rmsle:1.18596	validation_0-mae:7.09478	validation_1-rmsle:1.15100	validation_1-mae:6.63887
# [33]	validation_0-rmsle:1.17831	validation_0-mae:7.07039	validation_1-rmsle:1.14349	validation_1-mae:6.62232
# [34]	validation_0-rmsle:1.17060	validation_0-mae:7.04519	validation_1-rmsle:1.13604	validation_1-mae:6.59341
# [35]	validation_0-rmsle:1.16345	validation_0-mae:7.02467	validation_1-rmsle:1.12930	validation_1-mae:6.57339
# [36]	validation_0-rmsle:1.15635	validation_0-mae:7.00017	validation_1-rmsle:1.12238	validation_1-mae:6.54819
# [37]	validation_0-rmsle:1.14960	validation_0-mae:6.98297	validation_1-rmsle:1.11592	validation_1-mae:6.53478
# [38]	validation_0-rmsle:1.14307	validation_0-mae:6.95979	validation_1-rmsle:1.10967	validation_1-mae:6.50622
# [39]	validation_0-rmsle:1.13673	validation_0-mae:6.93779	validation_1-rmsle:1.10386	validation_1-mae:6.48417
# [40]	validation_0-rmsle:1.13063	validation_0-mae:6.91489	validation_1-rmsle:1.09794	validation_1-mae:6.46913
# [41]	validation_0-rmsle:1.12472	validation_0-mae:6.89382	validation_1-rmsle:1.09240	validation_1-mae:6.44482
# [42]	validation_0-rmsle:1.11898	validation_0-mae:6.87226	validation_1-rmsle:1.08684	validation_1-mae:6.43213
# [43]	validation_0-rmsle:1.11351	validation_0-mae:6.85674	validation_1-rmsle:1.08165	validation_1-mae:6.40817
# [44]	validation_0-rmsle:1.10825	validation_0-mae:6.83779	validation_1-rmsle:1.07661	validation_1-mae:6.38893
# [45]	validation_0-rmsle:1.10302	validation_0-mae:6.81549	validation_1-rmsle:1.07174	validation_1-mae:6.37711
# [46]	validation_0-rmsle:1.09814	validation_0-mae:6.79728	validation_1-rmsle:1.06725	validation_1-mae:6.35279
# [47]	validation_0-rmsle:1.09329	validation_0-mae:6.78059	validation_1-rmsle:1.06280	validation_1-mae:6.34155
# [48]	validation_0-rmsle:1.08873	validation_0-mae:6.76352	validation_1-rmsle:1.05835	validation_1-mae:6.32092
# [49]	validation_0-rmsle:1.08414	validation_0-mae:6.74491	validation_1-rmsle:1.05421	validation_1-mae:6.30582
# [50]	validation_0-rmsle:1.07991	validation_0-mae:6.72726	validation_1-rmsle:1.05004	validation_1-mae:6.29154
# [51]	validation_0-rmsle:1.07577	validation_0-mae:6.71053	validation_1-rmsle:1.04633	validation_1-mae:6.27059
# [52]	validation_0-rmsle:1.07170	validation_0-mae:6.69289	validation_1-rmsle:1.04256	validation_1-mae:6.25934
# [53]	validation_0-rmsle:1.06786	validation_0-mae:6.67681	validation_1-rmsle:1.03907	validation_1-mae:6.24326
# [54]	validation_0-rmsle:1.06412	validation_0-mae:6.66298	validation_1-rmsle:1.03571	validation_1-mae:6.22760
# [55]	validation_0-rmsle:1.06053	validation_0-mae:6.64639	validation_1-rmsle:1.03224	validation_1-mae:6.21383
# [56]	validation_0-rmsle:1.05698	validation_0-mae:6.62823	validation_1-rmsle:1.02909	validation_1-mae:6.19768
# [57]	validation_0-rmsle:1.05366	validation_0-mae:6.61409	validation_1-rmsle:1.02603	validation_1-mae:6.18348
# [58]	validation_0-rmsle:1.05035	validation_0-mae:6.60035	validation_1-rmsle:1.02305	validation_1-mae:6.16810
# [59]	validation_0-rmsle:1.04719	validation_0-mae:6.58231	validation_1-rmsle:1.02015	validation_1-mae:6.15585
# [60]	validation_0-rmsle:1.04417	validation_0-mae:6.56662	validation_1-rmsle:1.01723	validation_1-mae:6.14042
# [61]	validation_0-rmsle:1.04106	validation_0-mae:6.55504	validation_1-rmsle:1.01455	validation_1-mae:6.12524
# [62]	validation_0-rmsle:1.03827	validation_0-mae:6.53971	validation_1-rmsle:1.01201	validation_1-mae:6.11079
# [63]	validation_0-rmsle:1.03552	validation_0-mae:6.52421	validation_1-rmsle:1.00968	validation_1-mae:6.10152
# [64]	validation_0-rmsle:1.03277	validation_0-mae:6.51122	validation_1-rmsle:1.00708	validation_1-mae:6.08762
# [65]	validation_0-rmsle:1.03012	validation_0-mae:6.49955	validation_1-rmsle:1.00476	validation_1-mae:6.07460
# [66]	validation_0-rmsle:1.02771	validation_0-mae:6.48517	validation_1-rmsle:1.00256	validation_1-mae:6.06093
# [67]	validation_0-rmsle:1.02533	validation_0-mae:6.47247	validation_1-rmsle:1.00049	validation_1-mae:6.05128
# [68]	validation_0-rmsle:1.02294	validation_0-mae:6.45905	validation_1-rmsle:0.99840	validation_1-mae:6.03909
# [69]	validation_0-rmsle:1.02056	validation_0-mae:6.44690	validation_1-rmsle:0.99638	validation_1-mae:6.02616
# [70]	validation_0-rmsle:1.01845	validation_0-mae:6.43431	validation_1-rmsle:0.99447	validation_1-mae:6.01720
# [71]	validation_0-rmsle:1.01630	validation_0-mae:6.42224	validation_1-rmsle:0.99256	validation_1-mae:6.00675
# [72]	validation_0-rmsle:1.01437	validation_0-mae:6.41109	validation_1-rmsle:0.99095	validation_1-mae:5.99290
# [73]	validation_0-rmsle:1.01234	validation_0-mae:6.39895	validation_1-rmsle:0.98914	validation_1-mae:5.98449
# [74]	validation_0-rmsle:1.01043	validation_0-mae:6.38786	validation_1-rmsle:0.98740	validation_1-mae:5.97533
# [75]	validation_0-rmsle:1.00857	validation_0-mae:6.37545	validation_1-rmsle:0.98590	validation_1-mae:5.96269
# [76]	validation_0-rmsle:1.00677	validation_0-mae:6.36448	validation_1-rmsle:0.98424	validation_1-mae:5.95302
# [77]	validation_0-rmsle:1.00503	validation_0-mae:6.35233	validation_1-rmsle:0.98294	validation_1-mae:5.94069
# [78]	validation_0-rmsle:1.00342	validation_0-mae:6.34190	validation_1-rmsle:0.98156	validation_1-mae:5.93209
# [79]	validation_0-rmsle:1.00180	validation_0-mae:6.33131	validation_1-rmsle:0.98015	validation_1-mae:5.92225
# [80]	validation_0-rmsle:1.00028	validation_0-mae:6.32088	validation_1-rmsle:0.97876	validation_1-mae:5.91092
# [81]	validation_0-rmsle:0.99880	validation_0-mae:6.30913	validation_1-rmsle:0.97759	validation_1-mae:5.90088
# [82]	validation_0-rmsle:0.99741	validation_0-mae:6.30008	validation_1-rmsle:0.97643	validation_1-mae:5.89426
# [83]	validation_0-rmsle:0.99602	validation_0-mae:6.29007	validation_1-rmsle:0.97531	validation_1-mae:5.88204
# [84]	validation_0-rmsle:0.99472	validation_0-mae:6.27726	validation_1-rmsle:0.97427	validation_1-mae:5.87467
# [85]	validation_0-rmsle:0.99350	validation_0-mae:6.26901	validation_1-rmsle:0.97324	validation_1-mae:5.86575
# [86]	validation_0-rmsle:0.99229	validation_0-mae:6.25951	validation_1-rmsle:0.97221	validation_1-mae:5.85788
# [87]	validation_0-rmsle:0.99115	validation_0-mae:6.24898	validation_1-rmsle:0.97132	validation_1-mae:5.84760
# [88]	validation_0-rmsle:0.99003	validation_0-mae:6.24028	validation_1-rmsle:0.97049	validation_1-mae:5.84032
# [89]	validation_0-rmsle:0.98894	validation_0-mae:6.23266	validation_1-rmsle:0.96957	validation_1-mae:5.83246
# [90]	validation_0-rmsle:0.98798	validation_0-mae:6.22317	validation_1-rmsle:0.96878	validation_1-mae:5.82438
# [91]	validation_0-rmsle:0.98696	validation_0-mae:6.21549	validation_1-rmsle:0.96810	validation_1-mae:5.81798
# [92]	validation_0-rmsle:0.98603	validation_0-mae:6.20628	validation_1-rmsle:0.96739	validation_1-mae:5.80850
# [93]	validation_0-rmsle:0.98514	validation_0-mae:6.19846	validation_1-rmsle:0.96667	validation_1-mae:5.80163
# [94]	validation_0-rmsle:0.98428	validation_0-mae:6.19024	validation_1-rmsle:0.96599	validation_1-mae:5.79618
# [95]	validation_0-rmsle:0.98344	validation_0-mae:6.18196	validation_1-rmsle:0.96543	validation_1-mae:5.78968
# [96]	validation_0-rmsle:0.98264	validation_0-mae:6.17380	validation_1-rmsle:0.96483	validation_1-mae:5.78105
# [97]	validation_0-rmsle:0.98190	validation_0-mae:6.16658	validation_1-rmsle:0.96426	validation_1-mae:5.77499
# [98]	validation_0-rmsle:0.98116	validation_0-mae:6.15865	validation_1-rmsle:0.96377	validation_1-mae:5.76875
# [99]	validation_0-rmsle:0.98048	validation_0-mae:6.14999	validation_1-rmsle:0.96326	validation_1-mae:5.76107
# [100]	validation_0-rmsle:0.97984	validation_0-mae:6.14401	validation_1-rmsle:0.96282	validation_1-mae:5.75591
# [101]	validation_0-rmsle:0.97917	validation_0-mae:6.13700	validation_1-rmsle:0.96239	validation_1-mae:5.74550
# [102]	validation_0-rmsle:0.97862	validation_0-mae:6.12962	validation_1-rmsle:0.96197	validation_1-mae:5.74154
# [103]	validation_0-rmsle:0.97804	validation_0-mae:6.12324	validation_1-rmsle:0.96167	validation_1-mae:5.73824
# [104]	validation_0-rmsle:0.97751	validation_0-mae:6.11593	validation_1-rmsle:0.96130	validation_1-mae:5.73086
# [105]	validation_0-rmsle:0.97702	validation_0-mae:6.10855	validation_1-rmsle:0.96098	validation_1-mae:5.72277
# [106]	validation_0-rmsle:0.97659	validation_0-mae:6.10357	validation_1-rmsle:0.96070	validation_1-mae:5.71965
# [107]	validation_0-rmsle:0.97608	validation_0-mae:6.09584	validation_1-rmsle:0.96043	validation_1-mae:5.71507
# [108]	validation_0-rmsle:0.97563	validation_0-mae:6.09038	validation_1-rmsle:0.96022	validation_1-mae:5.70613
# [109]	validation_0-rmsle:0.97523	validation_0-mae:6.08323	validation_1-rmsle:0.95991	validation_1-mae:5.70113
# [110]	validation_0-rmsle:0.97484	validation_0-mae:6.07740	validation_1-rmsle:0.95974	validation_1-mae:5.69748
# [111]	validation_0-rmsle:0.97448	validation_0-mae:6.07135	validation_1-rmsle:0.95954	validation_1-mae:5.69210
# [112]	validation_0-rmsle:0.97410	validation_0-mae:6.06496	validation_1-rmsle:0.95933	validation_1-mae:5.68483
# [113]	validation_0-rmsle:0.97376	validation_0-mae:6.05871	validation_1-rmsle:0.95910	validation_1-mae:5.68065
# [114]	validation_0-rmsle:0.97349	validation_0-mae:6.05345	validation_1-rmsle:0.95900	validation_1-mae:5.67540
# [115]	validation_0-rmsle:0.97323	validation_0-mae:6.04802	validation_1-rmsle:0.95891	validation_1-mae:5.67214
# [116]	validation_0-rmsle:0.97296	validation_0-mae:6.04173	validation_1-rmsle:0.95877	validation_1-mae:5.66732
# [117]	validation_0-rmsle:0.97268	validation_0-mae:6.03686	validation_1-rmsle:0.95869	validation_1-mae:5.66050
# [118]	validation_0-rmsle:0.97247	validation_0-mae:6.03098	validation_1-rmsle:0.95865	validation_1-mae:5.65664
# [119]	validation_0-rmsle:0.97228	validation_0-mae:6.02683	validation_1-rmsle:0.95862	validation_1-mae:5.65479
# [120]	validation_0-rmsle:0.97209	validation_0-mae:6.02111	validation_1-rmsle:0.95867	validation_1-mae:5.65068
# [121]	validation_0-rmsle:0.97193	validation_0-mae:6.01590	validation_1-rmsle:0.95865	validation_1-mae:5.64368
# [122]	validation_0-rmsle:0.97173	validation_0-mae:6.01107	validation_1-rmsle:0.95859	validation_1-mae:5.64067
# [123]	validation_0-rmsle:0.97167	validation_0-mae:6.00630	validation_1-rmsle:0.95860	validation_1-mae:5.63792
# [124]	validation_0-rmsle:0.97153	validation_0-mae:6.00189	validation_1-rmsle:0.95866	validation_1-mae:5.63178
# [125]	validation_0-rmsle:0.97139	validation_0-mae:5.99674	validation_1-rmsle:0.95870	validation_1-mae:5.62780
# [126]	validation_0-rmsle:0.97132	validation_0-mae:5.99224	validation_1-rmsle:0.95877	validation_1-mae:5.62522
# [127]	validation_0-rmsle:0.97120	validation_0-mae:5.98793	validation_1-rmsle:0.95874	validation_1-mae:5.62093
# [128]	validation_0-rmsle:0.97113	validation_0-mae:5.98348	validation_1-rmsle:0.95891	validation_1-mae:5.61705
# [129]	validation_0-rmsle:0.97104	validation_0-mae:5.97924	validation_1-rmsle:0.95892	validation_1-mae:5.61361
# [130]	validation_0-rmsle:0.97102	validation_0-mae:5.97462	validation_1-rmsle:0.95903	validation_1-mae:5.61060
# [131]	validation_0-rmsle:0.97097	validation_0-mae:5.97050	validation_1-rmsle:0.95910	validation_1-mae:5.60668
# [132]	validation_0-rmsle:0.97098	validation_0-mae:5.96626	validation_1-rmsle:0.95931	validation_1-mae:5.60308
# [133]	validation_0-rmsle:0.97089	validation_0-mae:5.96231	validation_1-rmsle:0.95943	validation_1-mae:5.59973
# [134]	validation_0-rmsle:0.97085	validation_0-mae:5.95751	validation_1-rmsle:0.95951	validation_1-mae:5.59686
# [135]	validation_0-rmsle:0.97083	validation_0-mae:5.95422	validation_1-rmsle:0.95960	validation_1-mae:5.59306
# [136]	validation_0-rmsle:0.97088	validation_0-mae:5.94965	validation_1-rmsle:0.95978	validation_1-mae:5.59063
# [137]	validation_0-rmsle:0.97097	validation_0-mae:5.94649	validation_1-rmsle:0.95999	validation_1-mae:5.58760
# [138]	validation_0-rmsle:0.97095	validation_0-mae:5.94230	validation_1-rmsle:0.96010	validation_1-mae:5.58364
# [139]	validation_0-rmsle:0.97098	validation_0-mae:5.93895	validation_1-rmsle:0.96029	validation_1-mae:5.58124
# [140]	validation_0-rmsle:0.97100	validation_0-mae:5.93496	validation_1-rmsle:0.96042	validation_1-mae:5.57921
# [141]	validation_0-rmsle:0.97109	validation_0-mae:5.93180	validation_1-rmsle:0.96061	validation_1-mae:5.57559
# [142]	validation_0-rmsle:0.97108	validation_0-mae:5.92827	validation_1-rmsle:0.96075	validation_1-mae:5.57226
# [143]	validation_0-rmsle:0.97112	validation_0-mae:5.92439	validation_1-rmsle:0.96097	validation_1-mae:5.56987
# [144]	validation_0-rmsle:0.97125	validation_0-mae:5.92169	validation_1-rmsle:0.96116	validation_1-mae:5.56856
# [145]	validation_0-rmsle:0.97132	validation_0-mae:5.91798	validation_1-rmsle:0.96135	validation_1-mae:5.56593
# [146]	validation_0-rmsle:0.97144	validation_0-mae:5.91546	validation_1-rmsle:0.96159	validation_1-mae:5.56192
# [147]	validation_0-rmsle:0.97157	validation_0-mae:5.91153	validation_1-rmsle:0.96189	validation_1-mae:5.55985
# [148]	validation_0-rmsle:0.97166	validation_0-mae:5.90890	validation_1-rmsle:0.96210	validation_1-mae:5.55781
# [149]	validation_0-rmsle:0.97175	validation_0-mae:5.90561	validation_1-rmsle:0.96229	validation_1-mae:5.55576
# [150]	validation_0-rmsle:0.97185	validation_0-mae:5.90261	validation_1-rmsle:0.96253	validation_1-mae:5.55358
# [151]	validation_0-rmsle:0.97200	validation_0-mae:5.90013	validation_1-rmsle:0.96277	validation_1-mae:5.55132
# [152]	validation_0-rmsle:0.97219	validation_0-mae:5.89691	validation_1-rmsle:0.96307	validation_1-mae:5.54949
# [153]	validation_0-rmsle:0.97233	validation_0-mae:5.89478	validation_1-rmsle:0.96331	validation_1-mae:5.54770
# [154]	validation_0-rmsle:0.97246	validation_0-mae:5.89157	validation_1-rmsle:0.96359	validation_1-mae:5.54579
# [155]	validation_0-rmsle:0.97261	validation_0-mae:5.88913	validation_1-rmsle:0.96382	validation_1-mae:5.54354
# [156]	validation_0-rmsle:0.97277	validation_0-mae:5.88626	validation_1-rmsle:0.96408	validation_1-mae:5.54138
# [157]	validation_0-rmsle:0.97292	validation_0-mae:5.88374	validation_1-rmsle:0.96431	validation_1-mae:5.53987
# [158]	validation_0-rmsle:0.97306	validation_0-mae:5.88103	validation_1-rmsle:0.96457	validation_1-mae:5.53612
# [159]	validation_0-rmsle:0.97321	validation_0-mae:5.87867	validation_1-rmsle:0.96483	validation_1-mae:5.53544
# [160]	validation_0-rmsle:0.97344	validation_0-mae:5.87602	validation_1-rmsle:0.96518	validation_1-mae:5.53393
# [161]	validation_0-rmsle:0.97366	validation_0-mae:5.87387	validation_1-rmsle:0.96549	validation_1-mae:5.53234
# [162]	validation_0-rmsle:0.97381	validation_0-mae:5.87110	validation_1-rmsle:0.96576	validation_1-mae:5.53049
# [163]	validation_0-rmsle:0.97405	validation_0-mae:5.86946	validation_1-rmsle:0.96608	validation_1-mae:5.52786
# [164]	validation_0-rmsle:0.97423	validation_0-mae:5.86686	validation_1-rmsle:0.96637	validation_1-mae:5.52735
# [165]	validation_0-rmsle:0.97442	validation_0-mae:5.86486	validation_1-rmsle:0.96668	validation_1-mae:5.52646
# [166]	validation_0-rmsle:0.97467	validation_0-mae:5.86264	validation_1-rmsle:0.96701	validation_1-mae:5.52484
# [167]	validation_0-rmsle:0.97492	validation_0-mae:5.86107	validation_1-rmsle:0.96733	validation_1-mae:5.52233
# [168]	validation_0-rmsle:0.97505	validation_0-mae:5.85825	validation_1-rmsle:0.96757	validation_1-mae:5.52089
# [169]	validation_0-rmsle:0.97531	validation_0-mae:5.85669	validation_1-rmsle:0.96791	validation_1-mae:5.52035
# [170]	validation_0-rmsle:0.97558	validation_0-mae:5.85531	validation_1-rmsle:0.96829	validation_1-mae:5.51974
# [171]	validation_0-rmsle:0.97576	validation_0-mae:5.85293	validation_1-rmsle:0.96854	validation_1-mae:5.51809
# [172]	validation_0-rmsle:0.97604	validation_0-mae:5.85150	validation_1-rmsle:0.96892	validation_1-mae:5.51630
# [173]	validation_0-rmsle:0.97625	validation_0-mae:5.84898	validation_1-rmsle:0.96925	validation_1-mae:5.51484
# [174]	validation_0-rmsle:0.97647	validation_0-mae:5.84743	validation_1-rmsle:0.96957	validation_1-mae:5.51406
# [175]	validation_0-rmsle:0.97669	validation_0-mae:5.84576	validation_1-rmsle:0.96987	validation_1-mae:5.51331
# [176]	validation_0-rmsle:0.97696	validation_0-mae:5.84446	validation_1-rmsle:0.97024	validation_1-mae:5.51197
# [177]	validation_0-rmsle:0.97715	validation_0-mae:5.84228	validation_1-rmsle:0.97053	validation_1-mae:5.51094
# [178]	validation_0-rmsle:0.97743	validation_0-mae:5.84098	validation_1-rmsle:0.97088	validation_1-mae:5.50993
# [179]	validation_0-rmsle:0.97762	validation_0-mae:5.83921	validation_1-rmsle:0.97116	validation_1-mae:5.50932
# [180]	validation_0-rmsle:0.97789	validation_0-mae:5.83742	validation_1-rmsle:0.97151	validation_1-mae:5.50813
# [181]	validation_0-rmsle:0.97820	validation_0-mae:5.83656	validation_1-rmsle:0.97190	validation_1-mae:5.50701
# [182]	validation_0-rmsle:0.97841	validation_0-mae:5.83482	validation_1-rmsle:0.97218	validation_1-mae:5.50594
# [183]	validation_0-rmsle:0.97868	validation_0-mae:5.83325	validation_1-rmsle:0.97253	validation_1-mae:5.50526
# [184]	validation_0-rmsle:0.97888	validation_0-mae:5.83167	validation_1-rmsle:0.97285	validation_1-mae:5.50418
# [185]	validation_0-rmsle:0.97918	validation_0-mae:5.83060	validation_1-rmsle:0.97321	validation_1-mae:5.50380
# [186]	validation_0-rmsle:0.97934	validation_0-mae:5.82891	validation_1-rmsle:0.97346	validation_1-mae:5.50232
# [187]	validation_0-rmsle:0.97964	validation_0-mae:5.82759	validation_1-rmsle:0.97382	validation_1-mae:5.50199
# [188]	validation_0-rmsle:0.97994	validation_0-mae:5.82657	validation_1-rmsle:0.97419	validation_1-mae:5.50161
# [189]	validation_0-rmsle:0.98020	validation_0-mae:5.82508	validation_1-rmsle:0.97454	validation_1-mae:5.50105
# [190]	validation_0-rmsle:0.98049	validation_0-mae:5.82410	validation_1-rmsle:0.97490	validation_1-mae:5.50041
# [191]	validation_0-rmsle:0.98067	validation_0-mae:5.82282	validation_1-rmsle:0.97518	validation_1-mae:5.49912
# [192]	validation_0-rmsle:0.98097	validation_0-mae:5.82161	validation_1-rmsle:0.97554	validation_1-mae:5.49860
# [193]	validation_0-rmsle:0.98115	validation_0-mae:5.82029	validation_1-rmsle:0.97579	validation_1-mae:5.49820
# [194]	validation_0-rmsle:0.98147	validation_0-mae:5.81929	validation_1-rmsle:0.97615	validation_1-mae:5.49763

# %% [markdown]
# ### Mean Average Error (MAE)

# %%
from sklearn.metrics import mean_absolute_error
y_pred_base = regr_base.predict(X_test_base)
mae_base = mean_absolute_error(y_test_base, y_pred_base)
round(mae_base, 3)

# %% [markdown]
# ### Feature Importance

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    # print(df)
    print(pd.DataFrame(zip(base_train_columns, regr_base.feature_importances_), columns =['column', 'value']).sort_values('value', ascending=False))

# %% [markdown]
# ### Plot MAE convergence

# %%
import matplotlib.pyplot as plt
results = regr_base.evals_result()
epochs = len(results['validation_0']['mae'])
x_axis = range(0, epochs)


fig, ax = plt.subplots()
ax.plot(x_axis, results['validation_0']['mae'], label='Train')
ax.plot(x_axis, results['validation_1']['mae'], label='Test')
ax.legend()
